# %% [markdown]
# All the basic boolean operations:

# %%
print(2<10)
print(2>10)
# Out:
# True
# False

# %%
print(bool(2))
print(bool("Hello"))
print(bool(0))
print(bool(""))
print(bool(None))
print(bool("  ")) # Why is this not true?
print(bool("0")) # Why is this true?
print(bool([]))
# Out:
# True
# True
# False
# False
# False
# True
# True
# False
